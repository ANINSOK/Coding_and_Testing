# %% [markdown]
# ### [그래프] Silver II 1260 DFS와 BFS

# %% [markdown]
# 그래프를 DFS로 탐색한 결과와 BFS로 탐색한 결과를 출력하는 프로그램을 작성하시오. 단, 방문할 수 있는 정점이 여러 개인 경우에는 정점 번호가 작은 것을 먼저 방문하고, 더 이상 방문할 수 있는 점이 없는 경우 종료한다. 정점 번호는 1번부터 N번까지이다.

# %% [markdown]
# ### 입력
#
# 첫째 줄에 정점의 개수 N(1 ≤ N ≤ 1,000), 간선의 개수 M(1 ≤ M ≤ 10,000), 탐색을 시작할 정점의 번호 V가 주어진다. 다음 M개의 줄에는 간선이 연결하는 두 정점의 번호가 주어진다. 어떤 두 정점 사이에 여러 개의 간선이 있을 수 있다. 입력으로 주어지는 간선은 양방향이다.
#
# ### 출력
#
# 첫째 줄에 DFS를 수행한 결과를, 그 다음 줄에는 BFS를 수행한 결과를 출력한다. V부터 방문된 점을 순서대로 출력하면 된다.

# %% [markdown]
# ### 입출력 예
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 내 풀이

# %%
# 백준 제출 코드
def dfs(c):
    ans_dfs.append(c) # 방문 노드 추가
    v[c] = 1          # 방문 표시

    for n in adj[c]:
        if not v[n]:  # 방문하지 않은 노드인 경우
            dfs(n)    # 재귀함수 

def bfs(s):
    q = []            # 필요한 q, v[], 변수 생성

    q.append(s)       # Q에 초기데이터(들) 삽입
    ans_bfs.append(s) # 첫 방문 노드 기록 
    v[s] = 1          # 첫 방문 여부 기록

    while q:          # q에 데이터가 있는 동안
        c = q.pop(0)
        for n in adj[c]:
            if not v[n]:    # 방문하지 않은 노드일경우, q삽입
                q.append(n)
                ans_bfs.append(n)
                v[n] = 1

N, M, V = map(int, input().split())
adj = [[] for _ in range(N+1)]
for _ in range(M):
    s,e = map(int, input().split())
    adj[s].append(e)
    adj[e].append(s) # 양방향

# 오름차순 정렬
for i in range(1,N+1):
    adj[i].sort()

v = [0]*(N+1)       # 방문 여부 
ans_dfs = []        # 방문 순서    
dfs(V)

v = [0]*(N+1)       # 방문 여부 
ans_bfs = []        # 방문 순서 
bfs(V)

print(*ans_dfs)
print(*ans_bfs)
# Out:
# 3 1 2 5 4
# 3 1 4 2 5

# %%
N, M, V = map(int, input().split())
adj = [[] for _ in range(N+1)]
print(adj)

for _ in range(M):
    s,e = map(int, input().split())
    adj[s].append(e)
    adj[e].append(s) # 양방향
print(adj)

for i in range(1,N+1):
    adj[i].sort()
print(adj)

v = [0]*(N+1)
ans_dfs = []
print(v)
# Out:
# [[], [], [], [], [], []]
# [[], [2, 3], [5, 1], [4, 1], [5, 3], [4, 2]]
# [[], [2, 3], [1, 5], [1, 4], [3, 5], [2, 4]]
# [0, 0, 0, 0, 0, 0]
