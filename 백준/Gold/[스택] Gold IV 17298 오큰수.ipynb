# %% [markdown]
# ### [스택] Gold IV 17298 오큰수

# %% [markdown]
# ### 문제 설명
# 크기가 N인 수열 A = A1, A2, ..., AN이 있다. 수열의 각 원소 Ai에 대해서 오큰수 NGE(i)를 구하려고 한다. Ai의 오큰수는 오른쪽에 있으면서 Ai보다 큰 수 중에서 가장 왼쪽에 있는 수를 의미한다. 그러한 수가 없는 경우에 오큰수는 -1이다.
#
# 예를 들어, A = [3, 5, 2, 7]인 경우 NGE(1) = 5, NGE(2) = 7, NGE(3) = 7, NGE(4) = -1이다. A = [9, 5, 4, 8]인 경우에는 NGE(1) = -1, NGE(2) = 8, NGE(3) = 8, NGE(4) = -1이다.

# %% [markdown]
# ### 입력
#
# 첫째 줄에 수열 A의 크기 N (1 ≤ N ≤ 1,000,000)이 주어진다. 둘째 줄에 수열 A의 원소 A1, A2, ..., AN (1 ≤ Ai ≤ 1,000,000)이 주어진다.
#
# ### 출력
#
# 총 N개의 수 NGE(1), NGE(2), ..., NGE(N)을 공백으로 구분해 출력한다.

# %% [markdown]
# ### 입출력 예
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 내 풀이

# %%
# import sys
# n = map(int, sys.stdin.readline())
# a = list(map(int, sys.stdin.readline().split()))

# %%
def find_next_greater(nums):
    stack = [] # 원소 값을 저장하는 스택
    result = [-1] * len(nums)  # 결과를 저장할 리스트, 초기값은 -1

    for i in range(len(nums)):
        while stack and nums[stack[-1]] < nums[i]:  # 스택이 비어있지 않고 현재 원소가 스택의 맨 위 원소보다 크다면
            result[stack.pop()] = nums[i]  # 오큰수로 결정됨
            print(result)
        stack.append(i)  # 현재 원소의 인덱스를 스택에 저장
        print(stack)

    return result

# 입력 처리
import sys
n = map(int, sys.stdin.readline())
a = list(map(int, sys.stdin.readline().split()))

# 오큰수 찾기
next_greater = find_next_greater(a)

# 출력
print(*next_greater)

# %%
def find_next_greater(nums):
    stack = [] # 원소의 인덱스를 저장하는 스택
    result = [-1] * len(nums)  # 결과를 저장할 리스트, 초기값은 -1

    for i in range(len(nums)):
        while stack and nums[stack[-1]] < nums[i]:  # 스택이 비어있지 않고 현재 원소가 스택의 맨 위 원소보다 크다면
            result[stack.pop()] = nums[i]  # 오큰수로 결정됨
        stack.append(i)  # 현재 원소의 인덱스를 스택에 저장


    return result

# 입력 처리
import sys
n = 4
a = [9,5,4,8]

# 오큰수 찾기
next_greater = find_next_greater(a)

# 출력
print(*next_greater)
# Out:
# -1 8 8 -1
