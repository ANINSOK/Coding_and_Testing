# %% [markdown]
# ## LV_1. 비밀지도

# %% [markdown]
# 네오는 평소 프로도가 비상금을 숨겨놓는 장소를 알려줄 비밀지도를 손에 넣었다. 그런데 이 비밀지도는 숫자로 암호화되어 있어 위치를 확인하기 위해서는 암호를 해독해야 한다. 다행히 지도 암호를 해독할 방법을 적어놓은 메모도 함께 발견했다.
#
# 지도는 한 변의 길이가 n인 정사각형 배열 형태로, 각 칸은 "공백"(" ") 또는 "벽"("#") 두 종류로 이루어져 있다.
# 전체 지도는 두 장의 지도를 겹쳐서 얻을 수 있다. 각각 "지도 1"과 "지도 2"라고 하자. 지도 1 또는 지도 2 중 어느 하나라도 벽인 부분은 전체 지도에서도 벽이다. 지도 1과 지도 2에서 모두 공백인 부분은 전체 지도에서도 공백이다.
# "지도 1"과 "지도 2"는 각각 정수 배열로 암호화되어 있다.
# 암호화된 배열은 지도의 각 가로줄에서 벽 부분을 1, 공백 부분을 0으로 부호화했을 때 얻어지는 이진수에 해당하는 값의 배열이다.
#
# ![image.png](attachment:image.png)
#
# 네오가 프로도의 비상금을 손에 넣을 수 있도록, 비밀지도의 암호를 해독하는 작업을 도와줄 프로그램을 작성하라.

# %% [markdown]
# ### 입력 형식
# 입력으로 지도의 한 변 크기 n 과 2개의 정수 배열 arr1, arr2가 들어온다.
#
# - 1 ≦ n ≦ 16
# - arr1, arr2는 길이 n인 정수 배열로 주어진다.
# - 정수 배열의 각 원소 x를 이진수로 변환했을 때의 길이는 n 이하이다. 즉, 0 ≦ x ≦ 2n - 1을 만족한다.
#
#
# ### 출력 형식
# 원래의 비밀지도를 해독하여 '#', 공백으로 구성된 문자열 배열로 출력하라.

# %% [markdown]
# ### 입출력 예 #1
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 내 풀이

# %%
n = 5
arr1 = [9,20,28,18,11]
arr2 = [30,1,21,17,28]

# %%
def solution(n, arr1, arr2):
    trans_arr1 = []
    trans_arr2 = []
    result_trans_arr = []

    for i in arr1:
        tmp = bin(i)[2:]

        while n > len(tmp):
            tmp = str('0') + tmp
        
        trans_arr1.append(tmp)

    for i in arr2:
        tmp = bin(i)[2:]

        while n > len(tmp):
            tmp = str('0') + tmp

        trans_arr2.append(tmp)


    for num1, num2 in zip(trans_arr1, trans_arr2):
        sum_num = bin(int(num1, 2) | int(num2, 2))[2:].zfill(len(num1))
        result_trans_arr.append(sum_num)

    for i in range(len(result_trans_arr)):
        result_trans_arr[i] = result_trans_arr[i].replace('1', '#')
        result_trans_arr[i] = result_trans_arr[i].replace('0', ' ')
    return result_trans_arr

solution(n, arr1, arr2)
# Out:
# ['#####', '# # #', '### #', '#  ##', '#####']

# %% [markdown]
# ### 다른 사람 풀이

# %%
n = 5
arr1 = [9,20,28,18,11]
arr2 = [30,1,21,17,28]

# %%
def solution(n, arr1, arr2):
    answer = []
    for i,j in zip(arr1,arr2):
        a12 = str(bin(i|j)[2:])
        a12=a12.rjust(n,'0') # n보다 짧은 문자는 왼쪽부터 '0'으로 채워주세욧!
        a12=a12.replace('1','#')
        a12=a12.replace('0',' ')
        answer.append(a12)
    return answer

solution(n, arr1, arr2)
# Out:
# ['#####', '# # #', '### #', '#  ##', '#####']

# %%
for i,j in zip(arr1,arr2):
    a12 = str(bin(i|j)[2:])
    print(a12)
# Out:
# 11111
# 10101
# 11101
# 10011
# 11111

# %%
bin(i|j) # 30과 9의 비트 OR 연산을 수행한 결과인 31을 이진 형식으로 표현
rjust(n,'0') # n보다 짧은 문자는 왼쪽부터 '0'으로 채워주세욧!
