# %% [markdown]
# ## LV_1. 숫자 문자열과 영단어

# %% [markdown]
# 네오와 프로도가 숫자놀이를 하고 있습니다. 네오가 프로도에게 숫자를 건넬 때 일부 자릿수를 영단어로 바꾼 카드를 건네주면 프로도는 원래 숫자를 찾는 게임입니다.
#
# 다음은 숫자의 일부 자릿수를 영단어로 바꾸는 예시입니다.
#
# - 1478 → "one4seveneight"
# - 234567 → "23four5six7"
# - 10203 → "1zerotwozero3"
#
# 이렇게 숫자의 일부 자릿수가 영단어로 바뀌어졌거나, 혹은 바뀌지 않고 그대로인 문자열 s가 매개변수로 주어집니다. s가 의미하는 원래 숫자를 return 하도록 solution 함수를 완성해주세요.
#
# 참고로 각 숫자에 대응되는 영단어는 다음 표와 같습니다.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 제한사항

# %% [markdown]
# - 1 ≤ s의 길이 ≤ 50
# - s가 "zero" 또는 "0"으로 시작하는 경우는 주어지지 않습니다.
# - return 값이 1 이상 2,000,000,000 이하의 정수가 되는 올바른 입력만 s로 주어집니다.세요.

# %% [markdown]
# ### 입출력 예

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 입출력 예 #1
#
# 문제 예시와 같습니다.
#
# ### 입출력 예 #2
#
# 문제 예시와 같습니다.
#
# ### 입출력 예 #3
#
# "three"는 3, "six"는 6, "seven"은 7에 대응되기 때문에 정답은 입출력 예 #2와 같은 234567이 됩니다.
# 입출력 예 #2와 #3과 같이 같은 정답을 가리키는 문자열이 여러 가지가 나올 수 있습니다.
#
# ### 입출력 예 #4
#
# s에는 영단어로 바뀐 부분이 없습니다.

# %% [markdown]
# ### 내 풀이

# %%
s = "2three45sixseven"
import re

def solution(s):
    s_key = {"zero" : 0, "one": 1, "two" :2 ,"three" :3 ,"four" :4 ,"five" :5 ,"six" :6 ,"seven" :7 ,"eight" :8 ,"nine" :9}
    
    for i in s_key:
        s = re.sub(i, str(s_key[i]), s)
        
    return int(s)

solution(s)
# Out:
# 234567

# %% [markdown]
# ### 다른 사람 풀이

# %%
s = "2three45sixseven"

num_dic = {"zero":"0", "one":"1", "two":"2", "three":"3", "four":"4", "five":"5", "six":"6", "seven":"7", "eight":"8", "nine":"9"}

def solution(s):
    answer = s
    for key, value in num_dic.items():
        answer = answer.replace(key, value)
    return int(answer)
solution(s)
# Out:
# 234567

# %% [markdown]
# ## [python] 문자열 치환 총 정리 및 성능 비교(str.translate, str.replace, re.sub)
#
# replace는 속도가 빠르고 sub와 translate는 속도가 느리다.
#
# 정규표현식은 복잡한 문자열을 처리하기 용이하지만 속도가 느리고 작성하기에 어려움이 있다.
#
# 그리고 replace는 빠르긴 하나 특수한 조건을 걸어 복잡한 문자열을 처리하기에는 한계가 있다.
